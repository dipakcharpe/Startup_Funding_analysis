# %% [markdown]
# # EDA Project on StratupFunding in India
# - India has second most imerging startups country and Indian economy is more comfertable for stratups
# - we are looking for the trend in startup funding in India and yearly growth we can track sucsses rate of startups based on investmant reaisd each year
# - we performimng operations to find insights in the data
# -
#
#
# - Downloaded the data from kaggle "https://www.kaggle.com/datasets/sudalairajkumar/indian-startup-funding"
# - India startup economy is at its best for this time time this data contains satrtup funding details upto 2020
# - from this dataset we can track the yearly growth in total investments in different startup in different secotors
# - this data does not contain registration date of stratup,its only containg funding details by startup raised
# - This Dataset contain some critical name erroes in columns, Removed that error priorely by using Microsoft excel
# - Some startups change their names and industry the operates in,this data doesn,t contain any details of that

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\omcha\Downloads\startup_fund1.csv")

# %% [markdown]
# ## Data Preperation and Cleaning
# - 1.Load the file using pandas
# - 2.look some information about the data and columns
# - 3.fix any missing or incorrect values

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name    Industry Vertical  \
# 0         1      09-01-2020            BYJU?S               E-Tech
# 1         2      13-01-2020            Shuttl       Transportation
# 2         3      09-01-2020         Mamaearth           E-commerce
# 3         4      02-01-2020      wealthbucket              FinTech
# 4         5      02-01-2020            Fashor  Fashion and Apparel
# ...     ...             ...               ...                  ...
# 3039   3040      29-01-2015        Printvenue                  NaN
# 3040   3041      29-01-2015          Graphene                  NaN
# 3041   3042      30-01-2015    Mad Street Den                  NaN
# 3042   3043      30-01-2015         Simplotel                  NaN
# 3043   3044      31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# ...

# %%
df = df.rename(columns = {'Date dd/mm/yyyy': 'Date'})

# %%
df = df.rename(columns = {'City Location': 'City'})

# %%
df.isna().sum()
# Out:
# Sr No                   0
# Date                    0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD           0
# Remarks              2625
# Year                    0
# dtype: int64

# %%
df["City  Location"].unique()
# Out:
# array(['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune',
#        'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar',
#        'Delhi', 'Kormangala', 'Tulangan', 'Hyderabad', 'Burnsville',
#        'Menlo Park', 'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore',
#        'Taramani', 'Andheri', 'Chembur', 'Nairobi', 'Haryana', 'New York',
#        'Karnataka', 'Mumbai/Bengaluru', 'Bhopal',
#        'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US',
#        'Nagpur', 'Indore', 'New York, Bengaluru', 'California', 'India',
#        'Ahemadabad', 'Rourkela', 'Srinagar', 'Bhubneswar', 'Chandigarh',
#        'Delhi & Cambridge', 'Kolkatta', 'Kolkata', 'Coimbatore',
#        'Bangalore', 'Udaipur', nan, 'Ahemdabad', 'Bhubaneswar',
#        'Ahmedabad', 'Surat', 'Goa', 'Uttar Pradesh', 'Nw Delhi', 'Gaya',
#        'Vadodara', 'Trivandrum', 'Missourie', 'Panaji', 'Gwalior',
# ...

# %%
df["InvestmentnType"].unique()

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.Year
# Out:
# 0       2020
# 1       2020
# 2       2020
# 3       2020
# 4       2020
#         ...
# 3039    2015
# 3040    2015
# 3041    2015
# 3042    2015
# 3043    2015
# Name: Year, Length: 3044, dtype: int64

# %%
gk = df.groupby(['Year'])['Amount in USD'].sum()

# %%
gk
# Out:
# Year
# 2015    10,00,00056,00,0005,00,00020,00,00015,00,0001,...
# 2016    12,00,00040,00,00036,00,0001,00,00030,00,00014...
# 2017    1,23,00,0002,30,00,00010,00,0005,00,0006,00,00...
# 2018    10,00,00,0007,00,0005,00,00,0008,00,0005,72,00...
# 2019    60,00,0007,00,00,0005,00,00,0002,00,00,0001,20...
# 2020    20,00,00,00080,48,3941,83,58,86030,00,00018,00...
# Name: Amount in USD, dtype: object

# %%
df['Amount in USD'].unique()

# %%
df['Amount in USD'].dtype
# Out:
# dtype('O')

# %%
#df["Amount in USD"] = pd.to_numeric(df["Amount in USD"])
#df.dtypes

# %%
df["Amount in USD"].fillna("Undisclosed", inplace = True)

# %%
df["Amount in USD"].replace(to_replace ="N/A",value ="Undisclosed")
# Out:
# 0       20,00,00,000
# 1          80,48,394
# 2        1,83,58,860
# 3          30,00,000
# 4          18,00,000
#             ...
# 3039       45,00,000
# 3040        8,25,000
# 3041       15,00,000
# 3042     Undisclosed
# 3043        1,40,000
# Name: Amount in USD, Length: 3044, dtype: object

# %%
df["Amount in USD"].replace(to_replace ="unknown",value ="Undisclosed")
# Out:
# 0       20,00,00,000
# 1          80,48,394
# 2        1,83,58,860
# 3          30,00,000
# 4          18,00,000
#             ...
# 3039       45,00,000
# 3040        8,25,000
# 3041       15,00,000
# 3042     Undisclosed
# 3043        1,40,000
# Name: Amount in USD, Length: 3044, dtype: object

# %%
df["Amount in USD"].replace(to_replace ="undisclosed",value ="Undisclosed")
# Out:
# 0       20,00,00,000
# 1          80,48,394
# 2        1,83,58,860
# 3          30,00,000
# 4          18,00,000
#             ...
# 3039       45,00,000
# 3040        8,25,000
# 3041       15,00,000
# 3042     Undisclosed
# 3043        1,40,000
# Name: Amount in USD, Length: 3044, dtype: object

# %%
df.isna().sum()
# Out:
# Sr No                   0
# Date                    0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD           0
# Remarks              2625
# Year                    0
# dtype: int64

# %% [markdown]
# #### to perform agrigate functions on the data we need to seprate the startups that undisclose the investment

# %%
df_uda = df[df['Amount in USD'] == 'Undisclosed'] 
df_uda
# Out:
#       Sr No        Date     Startup Name  Industry Vertical  \
# 58       59  19-08-2019   Mishry Reviews           Services
# 112     113  01-02-2019           FleetX                 AI
# 139     140  22-11-2018         Skillbox     Social Network
# 144     145  01-10-2018        Northmist            Fashion
# 155     156  04-09-2018      HappyGoEasy  Consumer Internet
# ...     ...         ...              ...                ...
# 3027   3028  21-05-2015             Knit                NaN
# 3030   3031  22-01-2015        Freshmonk                NaN
# 3031   3032  22-01-2015  Englishleap.com                NaN
# 3035   3036  24-01-2015         Impartus                NaN
# 3042   3043  30-01-2015        Simplotel                NaN
#
#               SubVertical City  Location  \
# 58         Product Review        Gurgaon
# 112             Logistics        Gurgaon
# 139                   Art       Gurugram
# 144             Mens Wear          Delhi
# ...

# %%
df_dca = df[df['Amount in USD'] != 'Undisclosed' ]
df_dca = df_dca[df_dca['Amount in USD'] != 'undisclosed' ]
df_dca = df_dca[df_dca['Amount in USD'] != 'unknown']
df_dca
# Out:
#       Sr No        Date      Startup Name    Industry Vertical  \
# 0         1  09-01-2020            BYJU?S               E-Tech
# 1         2  13-01-2020            Shuttl       Transportation
# 2         3  09-01-2020         Mamaearth           E-commerce
# 3         4  02-01-2020      wealthbucket              FinTech
# 4         5  02-01-2020            Fashor  Fashion and Apparel
# ...     ...         ...               ...                  ...
# 3038   3039  28-01-2015     Grabhouse.com                  NaN
# 3039   3040  29-01-2015        Printvenue                  NaN
# 3040   3041  29-01-2015          Graphene                  NaN
# 3041   3042  30-01-2015    Mad Street Den                  NaN
# 3043   3044  31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# ...

# %% [markdown]
# - In above table df_dca we can see the amount of invetement is in string format and we need to convert it into integer to perfor certain operations
# - first we cheak how many values are their in str

# %%
#df_dca["Amount in USD"] = pd.to_numeric(df_dca["Amount in USD"])
#df_dca[["Amount in USD"]] = df_dca[["Amount in USD"]].apply(pd.to_numeric)
#df_dca.dtypes
df_dca[df_dca["Amount in USD"].apply(lambda x: isinstance(x, str))]
# Out:
#       Sr No        Date      Startup Name    Industry Vertical  \
# 0         1  09-01-2020            BYJU?S               E-Tech
# 1         2  13-01-2020            Shuttl       Transportation
# 2         3  09-01-2020         Mamaearth           E-commerce
# 3         4  02-01-2020      wealthbucket              FinTech
# 4         5  02-01-2020            Fashor  Fashion and Apparel
# ...     ...         ...               ...                  ...
# 3038   3039  28-01-2015     Grabhouse.com                  NaN
# 3039   3040  29-01-2015        Printvenue                  NaN
# 3040   3041  29-01-2015          Graphene                  NaN
# 3041   3042  30-01-2015    Mad Street Den                  NaN
# 3043   3044  31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# ...

# %%
df_dca['Amount in USD'] = df_dca['Amount in USD'].replace("," , "",regex=True).astype(float)

# %%
# Out:
#       Sr No        Date      Startup Name    Industry Vertical  \
# 0         1  09-01-2020            BYJU?S               E-Tech
# 1         2  13-01-2020            Shuttl       Transportation
# 2         3  09-01-2020         Mamaearth           E-commerce
# 3         4  02-01-2020      wealthbucket              FinTech
# 4         5  02-01-2020            Fashor  Fashion and Apparel
# ...     ...         ...               ...                  ...
# 3038   3039  28-01-2015     Grabhouse.com                  NaN
# 3039   3040  29-01-2015        Printvenue                  NaN
# 3040   3041  29-01-2015          Graphene                  NaN
# 3041   3042  30-01-2015    Mad Street Den                  NaN
# 3043   3044  31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# ...

# %%
df_dca["Amount in USD"] = pd.to_numeric(df_dca["Amount in USD"])
df_dca.dtypes
# Out:
# Sr No                  int64
# Date                  object
# Startup Name          object
# Industry Vertical     object
# SubVertical           object
# City  Location        object
# Investors Name        object
# InvestmentnType       object
# Amount in USD        float64
# Remarks               object
# Year                   int64
# dtype: object

# %%
df_dca.loc[pd.to_numeric(df['Amount in USD'], errors='coerce').isnull()]
# Out:
#       Sr No        Date      Startup Name    Industry Vertical  \
# 0         1  09-01-2020            BYJU?S               E-Tech
# 1         2  13-01-2020            Shuttl       Transportation
# 2         3  09-01-2020         Mamaearth           E-commerce
# 3         4  02-01-2020      wealthbucket              FinTech
# 4         5  02-01-2020            Fashor  Fashion and Apparel
# ...     ...         ...               ...                  ...
# 3038   3039  28-01-2015     Grabhouse.com                  NaN
# 3039   3040  29-01-2015        Printvenue                  NaN
# 3040   3041  29-01-2015          Graphene                  NaN
# 3041   3042  30-01-2015    Mad Street Den                  NaN
# 3043   3044  31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# ...

# %% [markdown]
#  - Convert amount in Milions for ease of operation

# %%
df_dca["Amount in USD"] = df_dca["Amount in USD"]/1000000

# %%
df_dca
# Out:
#       Sr No        Date      Startup Name    Industry Vertical  \
# 0         1  09-01-2020            BYJU?S               E-Tech
# 1         2  13-01-2020            Shuttl       Transportation
# 2         3  09-01-2020         Mamaearth           E-commerce
# 3         4  02-01-2020      wealthbucket              FinTech
# 4         5  02-01-2020            Fashor  Fashion and Apparel
# ...     ...         ...               ...                  ...
# 3038   3039  28-01-2015     Grabhouse.com                  NaN
# 3039   3040  29-01-2015        Printvenue                  NaN
# 3040   3041  29-01-2015          Graphene                  NaN
# 3041   3042  30-01-2015    Mad Street Den                  NaN
# 3043   3044  31-01-2015  couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# 0                                E-learning      Bengaluru
# 1                 App based shuttle service        Gurgaon
# ...

# %%
a= df_dca.groupby("Startup Name").count() > 1 
a['Sr No'] == True
# Out:
# Startup Name
# 19th mile               False
# 1mg                      True
# 1mg (Healthkartplus)    False
# 20Dresses               False
# 33Coupons               False
#                         ...
# trueHb                  False
# wWhere                  False
# wayForward              False
# wealthbucket            False
# zippserv                False
# Name: Sr No, Length: 1691, dtype: bool

# %%
foundation_cities = df_dca["City  Location"].value_counts()

# %%
foundation_cities
# Out:
# Bangalore     457
# Mumbai        402
# New Delhi     243
# Gurgaon       200
# Bengaluru     127
#              ...
# Bhubneswar      1
# Udaipur         1
# Surat           1
# Gaya            1
# Udupi           1
# Name: City  Location, Length: 86, dtype: int64

# %%
foundation_cities[:10].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - As we all well known that Bengluru is the startup Capital of India so more 500 stratups are located their but from above gap we are seeing that Banglore and Bengluru are two different graphs but that not correct as the name of the city is rechristened by karnataka govement may be thats startups founded before 2014
